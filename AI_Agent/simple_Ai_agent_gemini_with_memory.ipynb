# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuragdixit22081993/AIML-Task/blob/main/AI_Agent/simple_Ai_agent_gemini_with_memory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime

# %%
from google import genai
from google.colab import userdata

#API_KEY = put the new api key here created latest
api_key = userdata.get("GOOGLE_KEY")
client = genai.Client(api_key=api_key)

# %%
chat = client.chats.create(
    model="gemini-2.5-flash"
)

system_prompt = """
You are a helpful AI assistant.
Answer in simple English.
Be concise and accurate.
"""

chat.send_message(system_prompt)

print("AI Agent Ready (type exit to quit)\n")

while True:

    query = input("You: ")

    if query.lower() == "exit":
        break

    response = chat.send_message(query)

    print("\nAgent:", response.text)
    print()
# Out:
# AI Agent Ready (type exit to quit)
#
# You: Who i sachin
#
# Agent: Sachin is a famous **cricketer** from India.
#
# You: what i aseked earlier
#
# Agent: You asked: "Who is Sachin?"
