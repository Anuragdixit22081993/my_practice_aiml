# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuragdixit22081993/AIML-Task/blob/main/AI_Agent/Simple_Agent_gemini_key.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
from google.colab import userdata

#API_KEY = put the new api key here created latest
api_key = userdata.get("GOOGLE_KEY")
client = genai.Client(api_key=api_key)

# %%
from datetime import datetime

# %%
#client = genai.Client(api_key=API_KEY)

# Create a chat session
chat = client.chats.create(
    model="gemini-2.5-flash"
)

print("Agent started. Type 'exit' to quit.\n")

while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit"]:
        print("Goodbye!")
        break

    try:
        response = chat.send_message(user_input)

        print("\nAgent:")
        print(response.text)
        print()

    except Exception as e:
        print(f"Error: {e}")
# Out:
# Agent started. Type 'exit' to quit.
#
# You: who is sachin
#
# Agent:
# When people ask "Who is Sachin?", they are almost certainly referring to **Sachin Tendulkar**.
#
# **Sachin Tendulkar** is a legendary former Indian cricketer, widely regarded as one of the greatest batsmen of all time.
#
# Here's a summary of who he is:
#
# *   **Nationality:** Indian
# *   **Sport:** Cricket
# *   **Role:** Right-handed top-order batsman
# *   **Nicknames:** "Little Master," "Master Blaster," "God of Cricket"
#
# **Key Achievements and Significance:**
#
# 1.  **Most Runs in History:** He holds the record for the most runs scored in both Test and One Day International (ODI) cricket.
# 2.  **100 International Centuries:** He is the only cricketer in history to have scored 100 international centuries (51 in Tests and 49 in ODIs). This is a monumental and often cited record.
# ...
