# %% [markdown]
# <a href="https://colab.research.google.com/github/Anuragdixit22081993/my_practice_aiml/blob/main/Building_Agentic_AI_Systems/AI_Agent_Programs/Langgrapb-basics-Langchain-agents/Simple_Agent_bot_without_memory_using_lanchain_Langraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain-openai
# !pip install langgraph
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.4/120.4 kB 2.6 MB/s eta 0:00:00
# ...

# %%
# !pip install python-dotenv

# %%
from typing import TypedDict, List
from langchain_core.messages import HumanMessage
from langchain_openai import AzureChatOpenAI
from langgraph.graph import StateGraph, START, END
from dotenv import load_dotenv # used to store secret stuff like API keys or configuration values

from google.colab import userdata
import os
load_dotenv()
os.environ["AZURE_OPENAI_API_KEY"] = "e64fa339-47d1-4632-a388-0360cb74b5f2"
os.environ["AZURE_OPENAI_ENDPOINT"] = ("https://aicafe.hcl.com/AICafeService/api/v1/subscription/openai/"
    "deployments/gpt-4.1/chat/completions?api-version=2024-12-01-preview")
os.environ["OPENAI_API_VERSION"]="2024-12-01-preview"
class AgentState(TypedDict):
    messages: List[HumanMessage]

# Get the API key from environment variables

#openai_api_key = userdata.get("OPENAI_API_KEY")
#API_URL = (
   # "https://aicafe.hcl.com/AICafeService/api/v1/subscription/openai/"
   # "deployments/gpt-4.1/chat/completions?api-version=2024-12-01-preview"
#)
llm = AzureChatOpenAI(azure_deployment="gpt-4.1", temperature=0)

def process(state: AgentState) -> AgentState:
    response = llm.invoke(state["messages"])
    print(f"\nAI: {response.content}")
    return state

# %%
graph = StateGraph(AgentState)
graph.add_node("process", process)
graph.add_edge(START, "process")
graph.add_edge("process", END)
agent = graph.compile()

user_input = input("Enter: ")
while user_input != "exit":
    agent.invoke({"messages": [HumanMessage(content=user_input)]})
    user_input = input("Enter: ")
# Out:
# Enter: Who is amitabh bachhan
#
# AI: Amitabh Bachchan is a legendary Indian film actor, producer, television host, and former politician. Born on October 11, 1942, in Allahabad, India, he is widely regarded as one of the greatest and most influential actors in the history of Indian cinema. Often referred to as the "Shahenshah of Bollywood," "Star of the Millennium," or "Big B," Bachchan rose to fame in the early 1970s with iconic films such as **Zanjeer**, **Deewaar**, and **Sholay**.
#
# Over his career spanning more than five decades, Bachchan has appeared in over 200 Indian films and has won numerous awards, including several National Film Awards for Best Actor and many Filmfare Awards. He is known for his deep baritone voice, intense acting style, and versatility in portraying a wide range of characters.
#
# ...

# %%
from IPython.display import Image, display
display(Image(agent.get_graph().draw_mermaid_png()))
